# %%
import yaml
import xml.etree.ElementTree as ET

# Load the radii.yaml file
with open('vegetation_radii.yaml', 'r') as f:
    radii = yaml.safe_load(f)

# Parse the Gazebo world file
tree = ET.parse('dense_forest.world')
root = tree.getroot()

# %%
import os

# Initialize the obstacle counter
obstacle_id = 0

# Initialize the obstacles dictionary
obstacles = {}

# Loop through all the <model> tags
for model in root.findall('.//model'):
    if "Tree" in model.get('name') or "Bush" in model.get('name'):

        # Get the model name and radius from radii.yaml
        meshes = model.findall(".//uri")
        if not meshes:
            print(model.get("name"), " no tree or bush meshes")
            continue
        mesh_name =  meshes[0].text.strip()
        mesh_name = mesh_name.split(os.sep)[2]
        print(mesh_name, end=": ")
        if mesh_name not in radii:
            print("not found")
            continue

        radius = radii[mesh_name]

        # Get the model pose
        pose = model.find('pose').text.split()

        # Get the X and Y positions and convert them to floats
        x = float(pose[0])
        y = float(pose[1])

        # Add this obstacle to the obstacles dictionary
        d = {'x': x, 'y': y, 'r': radius, "model_name": model.get('name')}
        print(d)
        obstacles[obstacle_id] = d

        # Increment the obstacle ID counter
        obstacle_id += 1

# Save the obstacles dictionary to map.yaml
with open('dense_forest.yaml', 'w') as f:
    yaml.safe_dump({'obstacles': obstacles}, f)
# Out:
# tree_4: {'x': -4.09676, 'y': -1.48081, 'r': 6, 'model_name': 'Tree 4'}
# tree_4: {'x': -5.99458, 'y': 4.40763, 'r': 6, 'model_name': 'Tree 4_clone'}
# tree_4: {'x': 0.59282, 'y': 3.79577, 'r': 6, 'model_name': 'Tree 4_clone_0'}
# tree_4: {'x': 4.05214, 'y': -3.45088, 'r': 6, 'model_name': 'Tree 4_clone_1'}
# tree_4: {'x': 5.65986, 'y': 3.50511, 'r': 6, 'model_name': 'Tree 4_clone_2'}
# tree_4: {'x': -3.0868, 'y': -7.84555, 'r': 6, 'model_name': 'Tree 4_clone_3'}
# tree_4: {'x': -2.67992, 'y': 6.55404, 'r': 6, 'model_name': 'Tree 4_clone_4'}
# tree_4: {'x': 7.09997, 'y': 7.95608, 'r': 6, 'model_name': 'Tree 4_clone_5'}
# tree_4: {'x': -0.50347, 'y': -2.90306, 'r': 6, 'model_name': 'Tree 4_clone_6'}
# tree_4: {'x': 8.91411, 'y': -0.942577, 'r': 6, 'model_name': 'Tree 4_clone_7'}
# tree_4: {'x': 6.25927, 'y': -8.22753, 'r': 6, 'model_name': 'Tree 4_clone_8'}
# tree_3: {'x': 1.90396, 'y': 1.47093, 'r': 5, 'model_name': 'Tree 3'}
# tree_3: {'x': -4.18722, 'y': 0.997077, 'r': 5, 'model_name': 'Tree 3_clone'}
# tree_3: {'x': 0.506339, 'y': 7.77262, 'r': 5, 'model_name': 'Tree 3_clone_0'}
# tree_3: {'x': 1.81337, 'y': 6.98511, 'r': 5, 'model_name': 'Tree 3_clone_1'}
# tree_5: {'x': 1.53215, 'y': -6.59967, 'r': 2, 'model_name': 'Tree 5'}
# tree_5: {'x': 5.29143, 'y': -5.28726, 'r': 2, 'model_name': 'Tree 5_clone'}
# tree_5: {'x': 6.12243, 'y': -4.07602, 'r': 2, 'model_name': 'Tree 5_clone_0'}
# tree_5: {'x': 6.86464, 'y': 2.02302, 'r': 2, 'model_name': 'Tree 5_clone_1'}
# tree_5: {'x': -7.42578, 'y': -4.99475, 'r': 2, 'model_name': 'Tree 5_clone_2'}
# tree_5: {'x': -7.18349, 'y': 1.96175, 'r': 2, 'model_name': 'Tree 5_clone_3'}
# tree_1: {'x': -0.845654, 'y': -9.10169, 'r': 2, 'model_name': 'Tree 1'}
# tree_2: {'x': -0.483105, 'y': -1.86968, 'r': 4, 'model_name': 'Tree 2'}
# tree_5: {'x': 2.44768, 'y': -4.87592, 'r': 2, 'model_name': 'Tree 5_0'}
# tree_9: {'x': 2.86217, 'y': -0.651587, 'r': 2, 'model_name': 'Tree 9'}
# tree_9: {'x': -0.40374, 'y': 1.71359, 'r': 2, 'model_name': 'Tree 9_clone'}
# tree_9: {'x': -2.46652, 'y': -0.27951, 'r': 2, 'model_name': 'Tree 9_clone_0'}
# tree_9: {'x': -4.32318, 'y': 3.97464, 'r': 2, 'model_name': 'Tree 9_clone_1'}
# tree_7: {'x': 0.823122, 'y': -5.1089, 'r': 2, 'model_name': 'Tree 7'}
# tree_9: {'x': -4.79688, 'y': -5.89147, 'r': 2, 'model_name': 'Tree 9_clone_2'}
# tree_7: {'x': 0.781234, 'y': -4.42722, 'r': 2, 'model_name': 'Tree 7_clone'}
# tree_7: {'x': 1.63078, 'y': -4.3459, 'r': 2, 'model_name': 'Tree 7_clone_0'}
# tree_7: {'x': -6.6339, 'y': -0.059562, 'r': 2, 'model_name': 'Tree 7_clone_0_clone'}
# bush_2: {'x': 0.761908, 'y': -2.56617, 'r': 2, 'model_name': 'Bush 2'}
# bush_3: {'x': -0.168829, 'y': -3.26505, 'r': 2, 'model_name': 'Bush 3'}
# bush_5: {'x': -3.16499, 'y': -3.93963, 'r': 2, 'model_name': 'Bush 5'}
# bush_5: {'x': -2.83965, 'y': -3.48064, 'r': 2, 'model_name': 'Bush 5_0'}
# bush_0: {'x': 0.485426, 'y': 2.65857, 'r': 2, 'model_name': 'Bush 0'}
# bush_0: {'x': 2.97356, 'y': -7.76599, 'r': 2, 'model_name': 'Bush 0_0'}
# bush_0: {'x': 4.51754, 'y': 0.086489, 'r': 2, 'model_name': 'Bush 0_1'}
# bush_4: {'x': 8.47235, 'y': -5.13504, 'r': 2, 'model_name': 'Bush 4'}
# bush_3: {'x': 8.94884, 'y': -5.79851, 'r': 2, 'model_name': 'Bush 3_0'}
# bush_2: {'x': 8.93563, 'y': 7.46367, 'r': 2, 'model_name': 'Bush 2_0'}
# bush_2: {'x': 5.20701, 'y': 7.24724, 'r': 2, 'model_name': 'Bush 2_1'}
# tree_9: {'x': 8.38905, 'y': -8.02463, 'r': 2, 'model_name': 'Tree 9_0'}
# tree_9: {'x': 9.66007, 'y': -8.36648, 'r': 2, 'model_name': 'Tree 9_1'}
# tree_4: {'x': -6.81235, 'y': 8.72099, 'r': 6, 'model_name': 'Tree 4_0'}
# bush_5: {'x': 1.09545, 'y': -9.17195, 'r': 2, 'model_name': 'Bush 5_1'}
# tree_2: {'x': -8.80251, 'y': -0.34066, 'r': 4, 'model_name': 'Tree 2_0'}
# tree_9: {'x': 10.6908, 'y': 3.38344, 'r': 2, 'model_name': 'Tree 9_2'}
# bush_3: {'x': 8.51901, 'y': 2.75911, 'r': 2, 'model_name': 'Bush 3_1'}
# bush_2: {'x': 10.6857, 'y': 1.14009, 'r': 2, 'model_name': 'Bush 2_2'}
# bush_5: {'x': -1.70941, 'y': 8.93815, 'r': 2, 'model_name': 'Bush 5_2'}
# bush_2: {'x': -1.44595, 'y': 9.09246, 'r': 2, 'model_name': 'Bush 2_3'}
# bush_3: {'x': -3.14555, 'y': 9.37749, 'r': 2, 'model_name': 'Bush 3_2'}
# tree_3: {'x': 7.02994, 'y': -2.12178, 'r': 5, 'model_name': 'Tree 3_0'}
# tree_3: {'x': 4.72316, 'y': -9.8562, 'r': 5, 'model_name': 'Tree 3_1'}
# tree_3: {'x': -8.02105, 'y': -12.1285, 'r': 5, 'model_name': 'Tree 3_2'}
# tree_1: {'x': -6.36833, 'y': -11.4651, 'r': 2, 'model_name': 'Tree 1_0'}
# tree_2: {'x': -3.89184, 'y': -11.2176, 'r': 4, 'model_name': 'Tree 2_1'}
# tree_3: {'x': -12.5101, 'y': 8.86548, 'r': 5, 'model_name': 'Tree 3_3'}
# tree_9: {'x': 1.36155, 'y': -12.4766, 'r': 2, 'model_name': 'Tree 9_3'}
# tree_7: {'x': 2.64961, 'y': -12.8306, 'r': 2, 'model_name': 'Tree 7_0'}
# tree_4: {'x': -0.3332, 'y': -15.5438, 'r': 6, 'model_name': 'Tree 4_1'}
# tree_7: {'x': 5.44728, 'y': -13.5503, 'r': 2, 'model_name': 'Tree 7_clone_0_clone_0'}
# tree_4: {'x': 6.73288, 'y': -16.8246, 'r': 6, 'model_name': 'Tree 4_1_clone'}
# tree_4: {'x': 1.61386, 'y': 14.7792, 'r': 6, 'model_name': 'Tree 4_1_clone_0'}
# tree_4: {'x': -4.0, 'y': 15.0, 'r': 6, 'model_name': 'Tree 4_1_clone_1'}
# tree_4: {'x': -7.45442, 'y': 14.2209, 'r': 6, 'model_name': 'Tree 4_1_clone_2'}
# tree_4: {'x': -3.42497, 'y': 12.6632, 'r': 6, 'model_name': 'Tree 4_1_clone_3'}
# tree_4: {'x': -10.0138, 'y': 4.29817, 'r': 6, 'model_name': 'Tree 4_1_clone_4'}
# tree_4: {'x': -11.256, 'y': -8.13053, 'r': 6, 'model_name': 'Tree 4_1_clone_5'}
# tree_4: {'x': 5.92289, 'y': 12.8099, 'r': 6, 'model_name': 'Tree 4_1_clone_6'}
# tree_4: {'x': 5.99735, 'y': 21.326, 'r': 6, 'model_name': 'Tree 4_1_clone_7'}
# tree_4: {'x': 0.298571, 'y': 22.1312, 'r': 6, 'model_name': 'Tree 4_1_clone_8'}
# tree_4: {'x': -7.45172, 'y': 20.9719, 'r': 6, 'model_name': 'Tree 4_1_clone_9'}
# tree_4: {'x': -11.5138, 'y': 14.7752, 'r': 6, 'model_name': 'Tree 4_1_clone_10'}
# tree_4: {'x': 9.02427, 'y': -13.6979, 'r': 6, 'model_name': 'Tree 4_1_clone_11'}
# tree_4: {'x': 13.2176, 'y': -3.4257, 'r': 6, 'model_name': 'Tree 4_1_clone_12'}
# tree_3: {'x': 1.20207, 'y': 11.7727, 'r': 5, 'model_name': 'Tree 3_clone_2'}
# tree_3: {'x': -1.77144, 'y': 17.6557, 'r': 5, 'model_name': 'Tree 3_clone_3'}
# tree_3: {'x': -1.1713, 'y': 16.2028, 'r': 5, 'model_name': 'Tree 3_clone_4'}
# tree_3: {'x': -2.87369, 'y': 18.5827, 'r': 5, 'model_name': 'Tree 3_clone_5'}
# tree_3: {'x': -6.89529, 'y': 11.8135, 'r': 5, 'model_name': 'Tree 3_clone_6'}
# tree_3: {'x': -6.21502, 'y': 13.1051, 'r': 5, 'model_name': 'Tree 3_clone_7'}
# tree_3: {'x': -10.0026, 'y': 12.5594, 'r': 5, 'model_name': 'Tree 3_clone_8'}
# tree_3: {'x': -10.7466, 'y': 17.5438, 'r': 5, 'model_name': 'Tree 3_clone_9'}
# tree_3: {'x': -8.67734, 'y': -8.75003, 'r': 5, 'model_name': 'Tree 3_clone_10'}
# tree_5: {'x': -9.107, 'y': -3.30673, 'r': 2, 'model_name': 'Tree 5_clone_2_clone'}
# tree_5: {'x': 4.63636, 'y': 11.7118, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_0'}
# tree_5: {'x': -1.29027, 'y': 12.4832, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_1'}
# tree_5: {'x': 5.71972, 'y': 16.5378, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_2'}
# tree_5: {'x': 3.42434, 'y': 19.5783, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_3'}
# tree_5: {'x': 12.1278, 'y': 12.8074, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_4'}
# tree_5: {'x': 11.3262, 'y': 16.8811, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_5'}
# tree_5: {'x': 12.0084, 'y': 8.07083, 'r': 2, 'model_name': 'Tree 5_clone_2_clone_6'}
# bush_0: {'x': 3.85346, 'y': 10.3641, 'r': 2, 'model_name': 'Bush 0_1_clone'}
# bush_0: {'x': 7.79421, 'y': 11.4631, 'r': 2, 'model_name': 'Bush 0_1_clone_0'}
# bush_0: {'x': 1.75843, 'y': 17.948, 'r': 2, 'model_name': 'Bush 0_1_clone_1'}
# bush_0: {'x': -4.81076, 'y': 10.5832, 'r': 2, 'model_name': 'Bush 0_1_clone_2'}
# bush_0: {'x': -10.9388, 'y': 7.38385, 'r': 2, 'model_name': 'Bush 0_1_clone_3'}
# bush_0: {'x': -11.7265, 'y': 0.479194, 'r': 2, 'model_name': 'Bush 0_1_clone_4'}
# bush_0: {'x': -10.9185, 'y': -5.8042, 'r': 2, 'model_name': 'Bush 0_1_clone_5'}
# bush_0: {'x': 3.35749, 'y': -11.6755, 'r': 2, 'model_name': 'Bush 0_1_clone_6'}
# bush_0: {'x': 3.04504, 'y': -16.4227, 'r': 2, 'model_name': 'Bush 0_1_clone_7'}
# tree_7: {'x': 8.57491, 'y': -12.002, 'r': 2, 'model_name': 'Tree 7_clone_0_clone_0_clone'}
# tree_7: {'x': 8.82003, 'y': 13.5856, 'r': 2, 'model_name': 'Tree 7_clone_0_clone_0_clone_0'}
# tree_7: {'x': 3.68539, 'y': 14.5919, 'r': 2, 'model_name': 'Tree 7_clone_0_clone_0_clone_1'}
# tree_9: {'x': -0.250946, 'y': 6.26561, 'r': 2, 'model_name': 'Tree 9_clone_3'}
# tree_9: {'x': -0.693355, 'y': 7.19419, 'r': 2, 'model_name': 'Tree 9_clone_4'}
# tree_9: {'x': 2.39117, 'y': 9.75393, 'r': 2, 'model_name': 'Tree 9_clone_5'}
# tree_9: {'x': 2.82424, 'y': 10.614, 'r': 2, 'model_name': 'Tree 9_clone_6'}
# tree_9: {'x': 0.207473, 'y': 19.9974, 'r': 2, 'model_name': 'Tree 9_clone_7'}
# tree_9: {'x': -0.890004, 'y': 20.2781, 'r': 2, 'model_name': 'Tree 9_clone_8'}
# tree_9: {'x': -1.94974, 'y': 20.394, 'r': 2, 'model_name': 'Tree 9_clone_9'}
# tree_9: {'x': -5.03242, 'y': 19.1141, 'r': 2, 'model_name': 'Tree 9_clone_10'}
# tree_9: {'x': 9.33452, 'y': 17.9918, 'r': 2, 'model_name': 'Tree 9_clone_11'}
# tree_9: {'x': 13.2926, 'y': 17.845, 'r': 2, 'model_name': 'Tree 9_clone_12'}
# tree_5: {'x': 6.41154, 'y': -11.6716, 'r': 2, 'model_name': 'Tree 5_clone_0_clone'}
# tree_5: {'x': 11.4044, 'y': -10.4093, 'r': 2, 'model_name': 'Tree 5_clone_0_clone_0'}
# bush_5: {'x': -2.78399, 'y': 11.0473, 'r': 2, 'model_name': 'Bush 5_0_clone'}
# bush_5: {'x': -2.61224, 'y': 11.6589, 'r': 2, 'model_name': 'Bush 5_0_clone_0'}
# bush_5: {'x': -2.15949, 'y': 11.4495, 'r': 2, 'model_name': 'Bush 5_0_clone_1'}
